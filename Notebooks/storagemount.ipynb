# %%
confings = {
    "fs.azure.account.auth.type": "CustomAccessToken",
    "fs.azure.account.custom.token.provider.class": spark.conf.get("spark.databricks.passthrough.adls.gen2.tokenProviderClassName")
}
    
dbutils.fs.mount(
    source = "abfss://bronze@truststg.dfs.core.windows.net/",
    mount_point = "/mnt/bronze",
    extra_configs = confings
)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-7065941537797039>, line 6
#       1 confings = {
#       2     "fs.azure.account.auth.type": "CustomAccessToken",
#       3     "fs.azure.account.custom.token.provider.class": spark.conf.get("spark.databricks.passthrough.adls.gen2.tokenProviderClassName")
#       4 }
# ----> 6 dbutils.fs.mount(
#       7     source = "abfss://bronze@truststg.dfs.core.windows.net/",
#       8     mount_point = "/mnt/bronze",
#       9     extra_configs = confings
#      10 )
#
# File /databricks/python_shell/lib/dbruntime/dbutils.py:380, in DBUtils.FSHandler.prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     378 exc.__context__ = None
#     379 exc.__cause__ = None
# --> 380 raise exc
#
# ExecutionError: An error occurred while calling o413.mount.
# ...

# %%
dbutils.fs.ls("/mnt/bronze/SalesLT")
# Out:
# [FileInfo(path='dbfs:/mnt/bronze/SalesLT/Address/', name='Address/', size=0, modificationTime=1760027773000),
#  FileInfo(path='dbfs:/mnt/bronze/SalesLT/Customer/', name='Customer/', size=0, modificationTime=1760027808000),
#  FileInfo(path='dbfs:/mnt/bronze/SalesLT/CustomerAddress/', name='CustomerAddress/', size=0, modificationTime=1760027806000),
#  FileInfo(path='dbfs:/mnt/bronze/SalesLT/Product/', name='Product/', size=0, modificationTime=1760027804000),
#  FileInfo(path='dbfs:/mnt/bronze/SalesLT/ProductCategory/', name='ProductCategory/', size=0, modificationTime=1760027774000),
#  FileInfo(path='dbfs:/mnt/bronze/SalesLT/ProductDescription/', name='ProductDescription/', size=0, modificationTime=1760027815000),
#  FileInfo(path='dbfs:/mnt/bronze/SalesLT/ProductModel/', name='ProductModel/', size=0, modificationTime=1760027773000),
# ...

# %%
dbutils.fs.mount(
    source = "abfss://silver@truststg.dfs.core.windows.net/",
    mount_point = "/mnt/silver",
    extra_configs = confings
)   

dbutils.fs.mount(
    source = "abfss://gold@truststg.dfs.core.windows.net/",
    mount_point = "/mnt/gold",
    extra_configs = confings
)
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-7065941537797042>, line 1
# ----> 1 dbutils.fs.mount(
#       2     source = "abfss://silver@truststg.dfs.core.windows.net/",
#       3     mount_point = "/mnt/silver",
#       4     extra_configs = confings
#       5 )
#       7 dbutils.fs.mount(
#       8     source = "abfss://gold@truststg.dfs.core.windows.net/",
#       9     mount_point = "/mnt/gold",
#      10     extra_configs = confings
#      11 )
#
# File /databricks/python_shell/lib/dbruntime/dbutils.py:380, in DBUtils.FSHandler.prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#     378 exc.__context__ = None
#     379 exc.__cause__ = None
# --> 380 raise exc
#
# ExecutionError: An error occurred while calling o413.mount.
# ...
